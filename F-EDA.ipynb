# %%
### Imports
import pandas as pd
import numpy as np
from unicodedata import normalize

# %%
### Data upload - csv database
unicorns = pd.read_csv('List of Unicorns.csv')

# %%
### Data upload - wikipedia database
table_wiki = pd.read_html('https://en.wikipedia.org/wiki/List_of_unicorn_startup_companies')
wiki_unicorns = table_wiki[2]
wiki_unicorns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\frans\Documents\GitHub\Project-4_WebScraping\F-EDA.ipynb Celda 3 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/frans/Documents/GitHub/Project-4_WebScraping/F-EDA.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> ### Data upload - wikipedia database
# ----> <a href='vscode-notebook-cell:/c%3A/Users/frans/Documents/GitHub/Project-4_WebScraping/F-EDA.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> table_wiki = pd.read_html('https://en.wikipedia.org/wiki/List_of_unicorn_startup_companies')
#       <a href='vscode-notebook-cell:/c%3A/Users/frans/Documents/GitHub/Project-4_WebScraping/F-EDA.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> wiki_unicorns = table_wiki[2]
#       <a href='vscode-notebook-cell:/c%3A/Users/frans/Documents/GitHub/Project-4_WebScraping/F-EDA.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> wiki_unicorns
#
# File c:\Users\frans\anaconda3\envs\Data\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File c:\Users\frans\anaconda3\envs\Data\lib\site-packages\pandas\io\html.py:1205, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
#    1201 validate_header_arg(header)
#    1203 io = stringify_path(io)
# -> 1205 return _parse(
#    1206     flavor=flavor,
#    1207     io=io,
#    1208     match=match,
#    1209     header=header,
#    1210     index_col=index_col,
#    1211     skiprows=skiprows,
#    1212     parse_dates=parse_dates,
#    1213     thousands=thousands,
#    1214     attrs=attrs,
#    1215     encoding=encoding,
#    1216     decimal=decimal,
#    1217     converters=converters,
#    1218     na_values=na_values,
#    1219     keep_default_na=keep_default_na,
#    1220     displayed_only=displayed_only,
#    1221     extract_links=extract_links,
#    1222 )
#
# File c:\Users\frans\anaconda3\envs\Data\lib\site-packages\pandas\io\html.py:982, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, **kwargs)
#     980 retained = None
#     981 for flav in flavor:
# --> 982     parser = _parser_dispatch(flav)
#     983     p = parser(io, compiled_match, attrs, encoding, displayed_only, extract_links)
#     985     try:
#
# File c:\Users\frans\anaconda3\envs\Data\lib\site-packages\pandas\io\html.py:939, in _parser_dispatch(flavor)
#     937 else:
#     938     if not _HAS_LXML:
# --> 939         raise ImportError("lxml not found, please install it")
#     940 return _valid_parsers[flavor]
#
# ImportError: lxml not found, please install it

# %% [markdown]
# ### EDA - Unicorns File (downloaded database)

# %%
unicorns = unicorns.drop(['No.','Unnamed: 6','Unnamed: 7'], axis=1)
unicorns.head()
# Out:
#         Name                         Industry        Country  \
# 0  Bytedance          Artificial intelligence          China
# 1     SpaceX                            Other  United States
# 2      SHEIN  E-commerce & direct-to-consumer          China
# 3     Stripe                          Fintech  United States
# 4     Klarna                          Fintech         Sweden
#
#    Valuation ($ Billion)                                      Key Investors
# 0                  140.0  Sequoia Capital China, SIG Asia Investments, S...
# 1                  100.3  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2                  100.0  Tiger Global Management, Sequoia Capital China...
# 3                   95.0        Khosla Ventures, LowercaseCapital, capitalG
# 4                   45.6  Institutional Venture Partners, Sequoia Capita...
